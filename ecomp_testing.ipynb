# %%
import ecomp_test

# %%
ecomp_test.ecomp('UGEB_corrected.csv', 'UGEB_corrected.csv', 'UGEB_corrected_output.csv')
# Out:
# Start
# Path provided
# Outfile: UGEB_corrected_output.csv
# Step 1: Read input bulletins
# 18       59131713
# 13       59081445
# 16       59131711
# 12       59081376
# 2        59079797
#            ...
# 11682    59397482
# 11678    44189290
# 11680    59395810
# 11681    59395863
# 11679    44189291
# Name: ARID, Length: 12287, dtype: int32
#
# Step 2: Join bulletins on arrival time
# 	Stations:
# 		AAK
# 		AK01
# 		AK02
# 		AK08
# 		AK11
# 		AK16
# 		AK18
# 		AKASG
# 		AKTO
# 		ANMO
# 		ARCES
# 		ASAR
# 		ASF
# 		ATAH
# 		BATI
# 		BBB
# 		BBTS
# 		BDFB
# 		BORG
# 		BOSA
# 		BRTR
# 		BVAR
# 		CFAA
# 		CMAR
# 		CMIG
# 		CTA
# 		DAVOX
# 		DBIC
# 		DLBC
# 		DZM
# 		EIL
# 		EKA
# 		ELK
# 		ESDC
# 		FINES
# 		FITZ
# 		FRB
# 		GERES
# 		GEYT
# 		GNI
# 		GUMO
# 		H02N1
# 		H02S1
# 		H05N1
# 		H05S1
# 		H06E1
# 		H06S1
# 		H08N1
# 		H08N2
# 		H08N3
# 		H08S1
# 		H08S2
# 		H08S3
# 		H09N1
# 		H09W1
# 		H10N1
# 		H10N2
# 		H10N3
# 		H10S1
# 		H10S2
# 		H10S3
# 		H11N1
# 		H11N2
# ...

# %%
ecomp_test.ecomp('UGEB_corrected.csv', 'sel3_corrected.csv', 'UGEB_sel3_corrected_output.csv')
# Out:
# Start
# Path provided
# Outfile: UGEB_sel3_corrected_output.csv
# Step 1: Read input bulletins
# 18       59131713
# 13       59081445
# 16       59131711
# 12       59081376
# 2        59079797
#            ...
# 11682    59397482
# 11678    44189290
# 11680    59395810
# 11681    59395863
# 11679    44189291
# Name: ARID, Length: 12287, dtype: int32
#
# Step 2: Join bulletins on arrival time
# 	Stations:
# 		AAK
# 		AKASG
# 		AKTO
# 		ANMO
# 		ARCES
# 		ASAR
# 		ASF
# 		ATAH
# 		BATI
# 		BBB
# 		BBTS
# 		BDFB
# 		BORG
# 		BOSA
# 		BRTR
# 		BVAR
# 		CFAA
# 		CMAR
# 		CMIG
# 		CTA
# 		DAVOX
# 		DBIC
# 		DLBC
# 		EIL
# 		EKA
# 		ELK
# 		ESDC
# 		FINES
# 		FRB
# 		GERES
# 		GEYT
# 		GNI
# 		GUMO
# 		H01W1
# 		H01W2
# 		H01W3
# 		H02N1
# 		H02S1
# 		H05S1
# 		H06E1
# 		H06N1
# 		H06S1
# 		H07N1
# 		H07S1
# 		H08N1
# 		H08N2
# 		H08N3
# 		H08S1
# 		H08S2
# 		H08S3
# 		H09N1
# 		H09W1
# 		H10N1
# 		H10N2
# 		H10N3
# 		H10S1
# 		H10S2
# 		H10S3
# 		H11N1
# 		H11N2
# 		H11N3
# 		H11S1
# ...
